# %%
# %load_ext autoreload
# %autoreload 2
import sys, os
from os.path import expanduser
## actions required!!!!!!!!!!!!!!!!!!!! change your folder path 
path = "~/Documents/G3/MA-prediction"
path = expanduser(path)
sys.path.append(path)

import pandas as pd
import numpy as np

pd.options.mode.chained_assignment = None
import warnings
warnings.simplefilter(action='ignore', category=pd.errors.PerformanceWarning)
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
filepath = f"{path}/data/prediction-model/df_filtered.h5"
df = pd.read_hdf(filepath)

# %%
df.loc[df.retain, ['cash_term', 'pr']].sort_values('cash_term', ascending=False).head(50)
# Out:
#                 cash_term      pr
# master_deal_no
# 3890852020        848.020  848.02
# 1684872020        766.473   43.90
# 3342283020        331.500  331.50
# 3769478020        330.000  330.00
# 3089153020        315.000  315.00
# 3822220020        277.000  277.00
# 22781020          245.000  245.00
# 3331067020        235.000  235.00
# 2789583020        235.000  235.00
# 2762357020        232.000  232.00
# 3644610020        225.000  225.00
# 3095587020        222.930  317.00
# 3232429020        218.000  218.00
# 3759756020        203.000  203.00
# 2955022020        196.000  196.00
# 2714448020        190.000  190.00
# 3739045020        190.000  190.00
# 3303665020        190.000  190.00
# 3912535020        187.500  187.50
# 3142801020        180.000  180.00
# 3805445020        180.000  180.00
# 3615976020        177.500  177.50
# 3732887020        176.000  176.00
# 3895549020        170.000  170.00
# 3830696020        170.000  170.00
# 1864545020        160.000  160.00
# 751107020         160.000  160.00
# 3175586020        157.000  157.00
# 2145252020        150.000  150.00
# 3917838020        148.500  148.50
# 3275239020        145.000  145.00
# 3168570020        145.000  207.94
# 2820964020        143.000  143.00
# 3654597020        142.000  142.00
# 2676907020        140.000  140.00
# 2364013020        137.000  137.00
# 3367907020        136.500  136.50
# 2289520020        135.000  135.00
# 3151271020        134.500  134.50
# 3846599020        133.000  197.54
# 3873583020        132.000  132.00
# 2670189020        129.000  129.00
# 937303020         128.000  128.00
# 2751561020        127.200  127.20
# 2595789020        126.500  126.50
# 2757211020        125.000  230.12
# 3269691020        122.500  122.50
# 3420434020        120.300  188.24
# 3371414020        120.000  305.39
# 1862502020        120.000  120.00

# %%
df.cash_term[df.retain].sort_values(ascending=False).head(10)
# Out:
# master_deal_no
# 3890852020    848.020
# 1684872020    766.473
# 3342283020    331.500
# 3769478020    330.000
# 3089153020    315.000
# 3822220020    277.000
# 22781020      245.000
# 3331067020    235.000
# 2789583020    235.000
# 2762357020    232.000
# Name: cash_term, dtype: float64
